# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
csv_path = "USA NFL Arrest DATA.csv"
df = pd.read_csv(csv_path)

df.head(954)
# Out:
#            DATE TEAM              NAME POS      CASE            CATEGORY  \
# 0     1/17/2020   NE  Joejuan Williams  CB  Arrested               Drugs
# 1     1/16/2020  CLE     Odell Beckham  WR   Warrant             Battery
# 2     1/11/2020   NE    Julian Edelman  WR  Arrested           Vandalism
# 3    12/29/2019  MIA     Xavien Howard  CB  Arrested   Domestic violence
# 4    12/20/2019  PIT     Kameron Kelly   S  Arrested  Disorderly conduct
# ..          ...  ...               ...  ..       ...                 ...
# 949   2/16/2000   KC       Andre Rison  WR  Arrested               Theft
# 950    2/6/2000  NYJ     Wayne Chrebet  WR  Arrested  Disorderly conduct
# 951    2/6/2000  IND       Keith Elias  RB  Arrested  Disorderly conduct
# 952    2/5/2000  CIN       Steve Foley  LB  Arrested   Domestic violence
# 953    2/3/2000  CAR         Fred Lane  RB  Arrested          Drugs, gun
#
#                                            DESCRIPTION  \
# 0    Pulled over for speeding in Nashville, accused...
# 1    Accused of slapping the buttocks of a police o...
# 2    Accused of jumping on the hood of a Mercedes i...
# 3    Police in Davie, Fla., say he pushed his fianc...
# 4    Accused of making threats and resisting arrest...
# ..                                                 ...
# 949  Accused of renting but not returning a $1,100 ...
# 950  Accused of disorderly conduct in altercation o...
# 951  Accused of resisting arrest and disorderly con...
# 952  Accused of kicking in the door of his son's mo...
# 953  Police pulled him over in Jackson, Tenn., for ...
#
#                                                OUTCOME
# 0                             Resolution undetermined.
# 1                                   Warrant rescinded.
# 2                             Resolution undetermined.
# 3                             Resolution undetermined.
# 4    Resolution undetermined. Team released him sam...
# ..                                                 ...
# 949  Pleaded no contest, sentenced to one year of p...
# 950  Pleaded guilty to nuisance violation, fined $230.
# 951  Pleaded guilty to nuisance violation, fined $230.
# 952  Charge dropped after woman declined to cooperate.
# 953  Indicted but shot and killed by his wife in Ju...
#
# [954 rows x 8 columns]

# %%
new = df.CATEGORY.str.split(",", expand=True)
df['NEW'] = new[0]
reduced = df.loc[:,['POS', 'NEW']]
reduced
#counts = reduced['POS'].value_counts()
#counts_df = pd.DataFrame(counts)
#counts_df.index.names = ['pos']
#counts_df.rename(columns = {'POS':'freq'}, inplace = True) 
#counts_df
# Out:
#     POS                 NEW
# 0    CB               Drugs
# 1    WR             Battery
# 2    WR           Vandalism
# 3    CB   Domestic violence
# 4     S  Disorderly conduct
# ..   ..                 ...
# 951  RB  Disorderly conduct
# 952  LB   Domestic violence
# 953  RB               Drugs
# 954  LB              Murder
# 955  WR   Domestic violence
#
# [956 rows x 2 columns]

# %%
reduced.NEW.unique()
# Out:
# array(['Drugs', 'Battery', 'Vandalism', 'Domestic violence',
#        'Disorderly conduct', 'DUI', 'Assault', 'License',
#        'Public intoxication', 'Reckless driving', 'Eluding police',
#        'Trespassing', 'Insider trading', 'Domestic assault',
#        'Bomb threat', 'Injury to elderly', 'Sexual assault', 'Robbery',
#        'Selling alcohol to minor', 'Gun', 'Suspended license',
#        'Resisting arrest', 'Probation violation', 'Police interference',
#        'Violating court order', 'Traffic warrant', 'Hit-and-run',
#        'Outstanding warrant', 'Sexual battery', 'Burglary',
#        'Animal cruelty', 'Resisting officer', 'Evading arrest',
#        'Indecent exposure', 'Handicap parking', 'Theft', 'Child abuse',
#        'Speeding', 'Solicitation', 'Failure to Appear',
#        'Resisting Arrest', 'Child support', 'Failure to appear', 'Weapon',
#        'Murder', 'Attempted murder', 'Fraud', 'Criminal mischief',
#        'False name', 'Obstruction', 'Traffic warrants',
#        'Reckless endangerment', 'Sex', 'Stalking', 'Alcohol',
#        'Sexual abuse', 'Disturbing the peace', 'Public urination',
#        'Outstanding Warrant', 'Domestic dispute', 'Guns',
#        'Interfering with police', 'Manslaughter', 'Animal neglect',
#        'Dogfighting', 'Coercion', 'Pimping', 'Animal abuse',
#        'Evading police', 'Property destruction', 'Harassment',
#        'False information', 'Gambling', 'Breach of peace',
#        'Leaving scene.'], dtype=object)

# %%
#we need to figure out crime categories here
violent_crime = []
theft = []
fraud = []

# %%
df2 = reduced.groupby(['POS', 'NEW'])['POS'].count().unstack('NEW').fillna(0)
#df2.columns

df2.plot(kind='bar', stacked=True, legend = False, figsize=(20, 100))
plt.ylabel("Number of Crimes Comitted")
plt.legend(loc="best")

# %%
#make another that has crime type as tick marks on x axis and each bar counts nuber of crimes in that category

# %%
df3 = df['NEW'].value_counts()
#df3.plot(kind = 'bar')
df3.plot(kind='bar', figsize=(75, 100))
plt.ylabel("Number of Crimes Comitted")
plt.legend(loc="best")
