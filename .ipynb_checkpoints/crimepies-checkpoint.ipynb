# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
csv_path =  "Data Cleaning/Resources/NFL Arrest CSV.csv"
df = pd.read_csv(csv_path)

df.head(954)
# Out:
#            DATE TEAM              NAME POS      CASE            CATEGORY  \
# 0     1/17/2020   NE  Joejuan Williams  CB  Arrested               Drugs
# 1     1/16/2020  CLE     Odell Beckham  WR   Warrant             Battery
# 2     1/11/2020   NE    Julian Edelman  WR  Arrested           Vandalism
# 3    12/29/2019  MIA     Xavien Howard  CB  Arrested   Domestic violence
# 4    12/20/2019  PIT     Kameron Kelly   S  Arrested  Disorderly conduct
# ..          ...  ...               ...  ..       ...                 ...
# 949   2/16/2000   KC       Andre Rison  WR  Arrested               Theft
# 950    2/6/2000  NYJ     Wayne Chrebet  WR  Arrested  Disorderly conduct
# 951    2/6/2000  IND       Keith Elias  RB  Arrested  Disorderly conduct
# 952    2/5/2000  CIN       Steve Foley  LB  Arrested   Domestic violence
# 953    2/3/2000  CAR         Fred Lane  RB  Arrested          Drugs, gun
#
#                                            DESCRIPTION  \
# 0    Pulled over for speeding in Nashville, accused...
# 1    Accused of slapping the buttocks of a police o...
# 2    Accused of jumping on the hood of a Mercedes i...
# 3    Police in Davie, Fla., say he pushed his fianc...
# 4    Accused of making threats and resisting arrest...
# ..                                                 ...
# 949  Accused of renting but not returning a $1,100 ...
# 950  Accused of disorderly conduct in altercation o...
# 951  Accused of resisting arrest and disorderly con...
# 952  Accused of kicking in the door of his son's mo...
# 953  Police pulled him over in Jackson, Tenn., for ...
#
#                                                OUTCOME
# 0                             Resolution undetermined.
# 1                                   Warrant rescinded.
# 2                             Resolution undetermined.
# 3                             Resolution undetermined.
# 4    Resolution undetermined. Team released him sam...
# ..                                                 ...
# 949  Pleaded no contest, sentenced to one year of p...
# 950  Pleaded guilty to nuisance violation, fined $230.
# 951  Pleaded guilty to nuisance violation, fined $230.
# 952  Charge dropped after woman declined to cooperate.
# 953  Indicted but shot and killed by his wife in Ju...
#
# [954 rows x 8 columns]

# %%
new = df.CATEGORY.str.split(",", expand=True)
df['NEW'] = new[0]
df
# Out:
#            DATE TEAM              NAME POS      CASE            CATEGORY  \
# 0     1/17/2020   NE  Joejuan Williams  CB  Arrested               Drugs
# 1     1/16/2020  CLE     Odell Beckham  WR   Warrant             Battery
# 2     1/11/2020   NE    Julian Edelman  WR  Arrested           Vandalism
# 3    12/29/2019  MIA     Xavien Howard  CB  Arrested   Domestic violence
# 4    12/20/2019  PIT     Kameron Kelly   S  Arrested  Disorderly conduct
# ..          ...  ...               ...  ..       ...                 ...
# 951    2/6/2000  IND       Keith Elias  RB  Arrested  Disorderly conduct
# 952    2/5/2000  CIN       Steve Foley  LB  Arrested   Domestic violence
# 953    2/3/2000  CAR         Fred Lane  RB  Arrested          Drugs, gun
# 954   1/31/2000  BAL         Ray Lewis  LB   Charged              Murder
# 955   1/24/2000  DEN         Rod Smith  WR  Arrested   Domestic violence
#
#                                            DESCRIPTION  \
# 0    Pulled over for speeding in Nashville, accused...
# 1    Accused of slapping the buttocks of a police o...
# 2    Accused of jumping on the hood of a Mercedes i...
# 3    Police in Davie, Fla., say he pushed his fianc...
# 4    Accused of making threats and resisting arrest...
# ..                                                 ...
# 951  Accused of resisting arrest and disorderly con...
# 952  Accused of kicking in the door of his son's mo...
# 953  Police pulled him over in Jackson, Tenn., for ...
# 954  Accused of murder in the stabbing deaths of tw...
# 955  Accused of choking, beating and shoving his co...
#
#                                                OUTCOME                 NEW
# 0                             Resolution undetermined.               Drugs
# 1                                   Warrant rescinded.             Battery
# 2                             Resolution undetermined.           Vandalism
# 3                             Resolution undetermined.   Domestic violence
# 4    Resolution undetermined. Team released him sam...  Disorderly conduct
# ..                                                 ...                 ...
# 951  Pleaded guilty to nuisance violation, fined $230.  Disorderly conduct
# 952  Charge dropped after woman declined to cooperate.   Domestic violence
# 953  Indicted but shot and killed by his wife in Ju...               Drugs
# 954  Pleaded guilty to obstruction of justice, one ...              Murder
# 955  Pleaded guilty to misdemeanor count of verbal ...   Domestic violence
#
# [956 rows x 9 columns]

# %%
posdist = df['POS'].value_counts()
posdist = pd.DataFrame(posdist)
posdist = posdist.rename(columns = {'POS':'Number of Players In this Position'})
posdist.index.name = 'position'
posdist
# Out:
#           Number of Players In this Position
# position
# WR                                       155
# LB                                       137
# CB                                       126
# RB                                       107
# DT                                        89
# S                                         79
# DE                                        76
# OT                                        53
# TE                                        44
# OG                                        26
# QB                                        22
# FB                                        15
# K                                         12
# C                                          5
# DB                                         4
# P                                          3
# DE/DT                                      1
# OC                                         1
# OL                                         1

# %%
posdist.reset_index()
labels  = ['WR', 'LB', 'CB', 'RB', 'DT', 'S', 'DE', 'OT', 'TE', 'OG', 'QB', 'FB', 'K', 'C', 'DB', 'P', 'DE/DT', 'OC', 'OL']
num = posdist['Number of Players In this Position']
plt.pie(num, labels = labels, autopct="%1.1f%%")
plt.title("distribution of player positions")
plt.savefig("position distribution.png")

# %%
offense = ['WR', 'RB', 'OT', 'TE', 'QB', 'OC', 'OG', 'FB', 'K', 'OL', 'C', 'P']
defense = ['CB', 'S', 'DT', 'LB', 'DE', 'DB', 'DT']

# %%
combo_df = df[["POS", "NEW"]]
offense_df = df.loc[df.POS.isin(offense), ["POS", "NEW"]]
defense_df = df.loc[df.POS.isin(defense), ["POS", "NEW"]]
sizes = [len(offense_df), len(defense_df)]
labelz = ["offense Players", "Dewfense Players"]
plt.pie(sizes, labels = labelz, autopct="%1.1f%%")
plt.title("Distribution of offense vs deffense in player population")
plt.savefig("OFFVSDEFFPIE.png")

# %%
com_count = combo_df["POS"].value_counts()
com_count = pd.DataFrame(com_count)
com_count = com_count.rename(columns = {'POS':'Number of Crimes by players given offensive position'})
com_count.index.name = 'position'
com_count
# Out:
#           Number of Crimes by players given offensive position
# position
# WR                                                      155
# LB                                                      137
# CB                                                      126
# RB                                                      107
# DT                                                       89
# S                                                        79
# DE                                                       76
# OT                                                       53
# TE                                                       44
# OG                                                       26
# QB                                                       22
# FB                                                       15
# K                                                        12
# C                                                         5
# DB                                                        4
# P                                                         3
# DE/DT                                                     1
# OC                                                        1
# OL                                                        1

# %%
com_count.reset_index()
labels  = ['WR', 'LB', 'CB', 'RB', 'DT', 'S', 'DE', 'OT', 'TE', 'OG', 'QB', 'FB', 'K', 'C', 'DB', 'P', 'OL', 
           'DE/DT', 'OC']
num = com_count['Number of Crimes by players given offensive position']
plt.pie(num, labels = labels, autopct="%1.1f%%")
#FORMAT / MAKE PRETTY
plt.title("percent crime commited by each position")
plt.savefig("each position.png")

# %%
off_count = offense_df["POS"].value_counts()
off_count = pd.DataFrame(off_count)
off_count = off_count.rename(columns = {'POS':'Number of Crimes by players given offensive position'})
off_count.index.name = 'position'
off_count
# Out:
#           Number of Crimes by players given offensive position
# position
# WR                                                      155
# RB                                                      107
# OT                                                       53
# TE                                                       44
# OG                                                       26
# QB                                                       22
# FB                                                       15
# K                                                        12
# C                                                         5
# P                                                         3
# OL                                                        1
# OC                                                        1

# %%
off_count.reset_index()
labels  = ['WR', 'RB', 'OT', 'TE', 'OG', 'QB', 'FB', 'K', 'C', 'P', 'OL', 'OC']
num = off_count['Number of Crimes by players given offensive position']
plt.pie(num, labels = labels, autopct="%1.1f%%")
plt.title("percent crime commited by each offensive position")
plt.savefig("each offensive position.png")

# %%
def_count = defense_df["POS"].value_counts()
def_count = pd.DataFrame(def_count)
def_count = def_count.rename(columns = {'POS':'Number of Crimes by players given defensive position'})
def_count.index.name = 'position'
def_count
# Out:
#           Number of Crimes by players given defensive position
# position
# LB                                                      137
# CB                                                      126
# DT                                                       89
# S                                                        79
# DE                                                       76
# DB                                                        4

# %%
def_count.reset_index()
labels  = ['LB', 'CB', 'DT', 'S', 'DE', 'DB']
num = def_count['Number of Crimes by players given defensive position']
plt.pie(num, labels = labels, autopct="%1.1f%%")
plt.title("percent crime commited by each defensive position")
plt.savefig("each defensive position.png")
#FORMAT / MAKE PRETTY
