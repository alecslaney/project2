# %%
import pandas as pd

# %%
csv_path = "stadiums_nfl.csv"
df = pd.read_csv(csv_path, sep=';')

df.head()
# Out:
#                      Geo Point  \
# 0  39.90147005,"-75.1672900567
# 1     32.78322,"-117.119759969
# 2     35.22584,"-80.8533099799
# 3  30.32387005,"-81.6368999561
# 4  41.86250007,"-87.6167699762
#
#                                            Geo Shape              SECTOR  \
# 0  {""""type"""": """"Point"""""," """"coordinate...  High Value/Symboli
# 1  {""""type"""": """"Point"""""," """"coordinate...  High Value/Symboli
# 2  {""""type"""": """"Point"""""," """"coordinate...  High Value/Symboli
# 3  {""""type"""": """"Point"""""," """"coordinate...  High Value/Symboli
# 4  {""""type"""": """"Point"""""," """"coordinate...  High Value/Symboli
#
#       SUBSECTOR PRIMARY_TY     SEC_CLASS  DATE_CREAT  DATE_MODIF  COMP_AFFIL  \
# 0  Sports Arena        NFL  UNCLASSIFIED  2004-02-11  2010-02-11         NaN
# 1  Sports Arena        NFL  UNCLASSIFIED  2004-02-11  2010-02-11         NaN
# 2  Sports Arena        NFL  UNCLASSIFIED  2004-02-11  2010-02-11         NaN
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'TEAM,,,,'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-138669792cd2> in <module>
# ----> 1 df.loc['TEAM,,,,']
#
# ~\anaconda\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
# ...
