# %%
# Dependencies
import pandas as pd

# %%
# Read in file
file = 'Resources/clean_separated_list_count.csv'
df = pd.read_csv(file, encoding="ISO-8859-1")
df.head()
# Out:
#          date team            player position    status            crimeraw  \
# 0   1/17/2020   NE  Joejuan Williams       CB  Arrested               drugs
# 1   1/16/2020  CLE     Odell Beckham       WR   Warrant             battery
# 2   1/11/2020   NE    Julian Edelman       WR  Arrested           vandalism
# 3  12/29/2019  MIA     Xavien Howard       CB  Arrested   domestic violence
# 4  12/20/2019  PIT     Kameron Kelly        S  Arrested  disorderly conduct
#
#                                                 desc  \
# 0  Pulled over for speeding in Nashville, accused...
# 1  Accused of slapping the buttocks of a police o...
# 2  Accused of jumping on the hood of a Mercedes i...
# 3  Police in Davie, Fla., say he pushed his fianc...
# 4  Accused of making threats and resisting arrest...
#
#                                              outcome              crime1  \
# 0                           Resolution undetermined.               drugs
# 1                                 Warrant rescinded.             battery
# 2                           Resolution undetermined.           vandalism
# 3                           Resolution undetermined.   domestic violence
# 4  Resolution undetermined. Team released him sam...  disorderly conduct
#
#   crime2 crime3              crime_list  crime_count
# 0    NaN    NaN               ['drugs']            1
# 1    NaN    NaN             ['battery']            1
# 2    NaN    NaN           ['vandalism']            1
# 3    NaN    NaN   ['domestic violence']            1
# 4    NaN    NaN  ['disorderly conduct']            1

# %%
# Splits "crimeraw" category into individual rows based on how many crimes are in list
reshape = \
(df.set_index(df.columns.drop('crimeraw',1).tolist())
   .crimeraw.str.split(',', expand=True)
   .stack()
   .reset_index()
   .rename(columns={0:'crimeraw'})
   .loc[:, df.columns]
)

df = pd.DataFrame(reshape)
df.head(10)
# Out:
#          date team            player position    status            crimeraw  \
# 0   1/17/2020   NE  Joejuan Williams       CB  Arrested               drugs
# 1   1/16/2020  CLE     Odell Beckham       WR   Warrant             battery
# 2   1/11/2020   NE    Julian Edelman       WR  Arrested           vandalism
# 3  12/29/2019  MIA     Xavien Howard       CB  Arrested   domestic violence
# 4  12/20/2019  PIT     Kameron Kelly        S  Arrested  disorderly conduct
# 5   12/3/2019  DAL     Antwaun Woods       DT  Arrested               drugs
# 6  11/19/2019  MIA       Mark Walton       RB  Arrested   domestic violence
# 7   11/6/2019  DAL       Daniel Ross       DT  Arrested               drugs
# 8   11/6/2019  DAL       Daniel Ross       DT  Arrested                 gun
# 9  10/27/2019  MIN     Jayron Kearse        S  Arrested                 dui
#
#                                                 desc  \
# 0  Pulled over for speeding in Nashville, accused...
# 1  Accused of slapping the buttocks of a police o...
# 2  Accused of jumping on the hood of a Mercedes i...
# 3  Police in Davie, Fla., say he pushed his fianc...
# 4  Accused of making threats and resisting arrest...
# 5  Pulled over for speeding in Frisco, Texas, and...
# 6  Police say he punched his pregnant girlfriend ...
# 7  Accused of marijuana possession and unlawful c...
# 8  Accused of marijuana possession and unlawful c...
# 9  Accused of driving drunk in Minneapolis, with ...
#
#                                              outcome              crime1  \
# 0                           Resolution undetermined.               drugs
# 1                                 Warrant rescinded.             battery
# 2                           Resolution undetermined.           vandalism
# 3                           Resolution undetermined.   domestic violence
# 4  Resolution undetermined. Team released him sam...  disorderly conduct
# 5                            Resolution undetermined               drugs
# 6  Resolution undetermined. Team released him sam...   domestic violence
# 7                           Resolution undetermined.               drugs
# 8                           Resolution undetermined.               drugs
# 9                           Resolution undetermined.                 dui
#
#    crime2 crime3              crime_list  crime_count
# 0     NaN    NaN               ['drugs']            1
# 1     NaN    NaN             ['battery']            1
# 2     NaN    NaN           ['vandalism']            1
# 3     NaN    NaN   ['domestic violence']            1
# 4     NaN    NaN  ['disorderly conduct']            1
# 5     NaN    NaN               ['drugs']            1
# 6     NaN    NaN   ['domestic violence']            1
# 7     gun    NaN       ['drugs', ' gun']            2
# 8     gun    NaN       ['drugs', ' gun']            2
# 9   drugs    NaN       ['dui', ' drugs']            2

# %%
# Cleaning up crime labels, renamed crimeraw to crime
df = df.rename(columns={"crimeraw":"crime"})
df.crime = df.crime.replace({
 ' assault': 'assault',
 ' battery': 'battery',
 ' child abuse': 'child abuse',
 ' disorderly conduct': 'disorderly conduct',
 ' drugs': 'drugs',
 ' privacy invasion': 'privacy invasion',
 ' rape': 'rape',
 ' reckless driving': 'reckless endangerment',
 ' resisting arrest': 'resisting arrest',   
 ' alcohol': 'alcohol - other',
 ' gun': 'firearms',
 ' guns':'firearms',
 ' license': 'traffic - other',
 ' manslaughter': 'murder',
 ' resisting arrrest': 'resisting arrest',
 ' sex': 'sex - other',
 ' stolen possession': 'theft',
 ' weapon': 'weapons',
 'alcohol': 'alcohol - other',
 'animal cruelty': 'animal abuse',
 'animal neglect': 'animal abuse',
 'disturbing the peace': 'disorderly conduct',
 'dogfighting': 'animal abuse',
 'domestic assault': 'domestic violence',
 'domestic dispute': 'domestic violence',
 'eluding police': 'evading police',
 'evading arrest': 'evading police',
 'false information': 'fraud',
 'false name': 'fraud',
 'gun': 'firearms',
 'guns': 'firearms',
 'handicap parking': 'traffic - other',
 'interfering with police': 'obstruction',
 'license': 'traffic - other',
 'leaving scene.': 'leaving scene',
 'manslaughter': 'murder',
 'police interference': 'obstruction',
 'public intoxication': 'alcohol - other',
 'reckless driving' : 'reckless endangerment',
 'reckless endagerment': 'reckless endangerment',
 'resisting officer': 'resisting arrest',
 'selling alcohol to minor': 'alcohol - other',
 'sex' : 'sex - other',
 'sexual assault': 'sexual abuse',
 'sexual battery': 'sexual abuse',
 'solicitation' : 'sex - other',
 'speeding': 'traffic - other',
 'suspended license': 'traffic - other',
 'traffic warrant': 'traffic - other',
 'traffic warrants': 'traffic - other',
 'weapon': 'weapons'})

# %%
df = df[['date', 'team', 'player', 'position', 'crime', 'desc']]
df.head()
# Out:
#          date team            player position               crime  \
# 0   1/17/2020   NE  Joejuan Williams       CB               drugs
# 1   1/16/2020  CLE     Odell Beckham       WR             battery
# 2   1/11/2020   NE    Julian Edelman       WR           vandalism
# 3  12/29/2019  MIA     Xavien Howard       CB   domestic violence
# 4  12/20/2019  PIT     Kameron Kelly        S  disorderly conduct
#
#                                                 desc
# 0  Pulled over for speeding in Nashville, accused...
# 1  Accused of slapping the buttocks of a police o...
# 2  Accused of jumping on the hood of a Mercedes i...
# 3  Police in Davie, Fla., say he pushed his fianc...
# 4  Accused of making threats and resisting arrest...

# %%
df.to_csv('Resources/crime_split.csv', index=False)
