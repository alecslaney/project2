# %%
# Dependencies
import pandas as pd

# %%
# Reading in dataframes
offense_df = pd.read_csv('Resources/offense_crime.csv')
defense_df = pd.read_csv('Resources/defense_crime.csv')
df = pd.read_csv('Resources/clean.csv')
df.head()
# Out:
#          date team            player position    status            crimeraw  \
# 0   1/17/2020   NE  Joejuan Williams       CB  Arrested               drugs
# 1   1/16/2020  CLE     Odell Beckham       WR   Warrant             battery
# 2   1/11/2020   NE    Julian Edelman       WR  Arrested           vandalism
# 3  12/29/2019  MIA     Xavien Howard       CB  Arrested   domestic violence
# 4  12/20/2019  PIT     Kameron Kelly        S  Arrested  disorderly conduct
#
#                                                 desc  \
# 0  Pulled over for speeding in Nashville, accused...
# 1  Accused of slapping the buttocks of a police o...
# 2  Accused of jumping on the hood of a Mercedes i...
# 3  Police in Davie, Fla., say he pushed his fianc...
# 4  Accused of making threats and resisting arrest...
#
#                                              outcome              crime1  \
# 0                           Resolution undetermined.               drugs
# ...

# %%
# Change the string to whatever crime you're trying to filter the dataset by
target_crime = "drugs"
target_df = df[df.crimeraw.str.contains(target_crime)]
target_df
# Out:
#            date team                player position       status  \
# 0     1/17/2020   NE      Joejuan Williams       CB     Arrested
# 5     12/3/2019  DAL         Antwaun Woods       DT     Arrested
# 7     11/6/2019  DAL           Daniel Ross       DT     Arrested
# 8    10/27/2019  MIN         Jayron Kearse        S     Arrested
# 11    10/2/2019  JAC        Marcell Dareus       DT        Cited
# 14     8/8/2019   NE         Patrick Chung        S     Indicted
# 22     4/4/2019  CIN           Mark Walton       RB  Surrendered
# 24     3/1/2019  BAL          Alex Collins       RB     Arrested
# 29    1/26/2019   KC    De''Anthony Thomas       WR     Arrested
# 31    1/16/2019  MIN            Roc Thomas       RB     Arrested
# 32    1/16/2019  CIN           Mark Walton       RB      Charged
# 38    8/31/2018  DAL          Rico Gathers       TE     Arrested
# 41     8/5/2018  CLE      Antonio Callaway       WR        Cited
# ...

# %%
target_df.to_csv('Resources/target_crime.csv', index=False)
